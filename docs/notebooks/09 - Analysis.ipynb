# %% [markdown]
# # Analysis

# %% [markdown]
# ## 1. Setup

# %%
# Imports
from PIL import Image
import numpy as np
import pandas as pd

# %%
# User Variables & Parameters
# Reading
filePath                = '../output/concat+WET_ISB.csv'
DF                      = pd.read_csv(filePath)

# %% [markdown]
# ## 2. Visualization

# %%
DF
# Out:
#      Unnamed: 0 prec_FileName  prec_AverageValues  prec_MedianValues  \
# 0             0       01-1961           124.33631         124.666230
# 1             1       02-1961            48.05422          46.615837
# 2             2       03-1961            37.08085          36.371494
# 3             3       04-1961           101.93873          98.143430
# 4             4       05-1961            20.18084          18.558178
# ..          ...           ...                 ...                ...
# 727         727       08-2021                 NaN                NaN
# 728         728       09-2021                 NaN                NaN
# 729         729       10-2021                 NaN                NaN
# 730         730       11-2021                 NaN                NaN
# 731         731       12-2021                 NaN                NaN
#
#      prec_MinValues  prec_MaxValues  prec_Variance  prec_StandardDeviation  \
# ...

# %%
# Dropping first columns
DF                      = DF.drop(DF.columns[[0]], axis=1)
DF
# Out:
#     prec_FileName  prec_AverageValues  prec_MedianValues  prec_MinValues  \
# 0         01-1961           124.33631         124.666230       92.453400
# 1         02-1961            48.05422          46.615837       36.605957
# 2         03-1961            37.08085          36.371494       24.608969
# 3         04-1961           101.93873          98.143430       58.204906
# 4         05-1961            20.18084          18.558178       13.218128
# ..            ...                 ...                ...             ...
# 727       08-2021                 NaN                NaN             NaN
# 728       09-2021                 NaN                NaN             NaN
# 729       10-2021                 NaN                NaN             NaN
# 730       11-2021                 NaN                NaN             NaN
# 731       12-2021                 NaN                NaN             NaN
#
#      prec_MaxValues  prec_Variance  prec_StandardDeviation  \
# ...

# %%
DF.plot.line(figsize=((30,10)))
# Out:
# <AxesSubplot:>

# %%
filePath                = '../output/concat_ISB.csv'
DF                      = pd.read_csv(filePath)
DF                      = DF.drop(DF.columns[[0]], axis=1)
display(DF)
DF.plot.line(figsize=((30,10)))
# Out:
#     prec_FileName  prec_AverageValues  prec_MedianValues  prec_MinValues  \
# 0         01-1961          124.336310         124.666230       92.453400
# 1         02-1961           48.054220          46.615837       36.605957
# 2         03-1961           37.080850          36.371494       24.608969
# 3         04-1961          101.938730          98.143430       58.204906
# 4         05-1961           20.180840          18.558178       13.218128
# ..            ...                 ...                ...             ...
# 691       08-2018          167.790650         167.583150      109.616340
# 692       09-2018           71.050530          72.789450       48.928480
# 693       10-2018           14.812920          13.332123        6.623239
# 694       11-2018           22.134710          20.666344        8.053539
# 695       12-2018           13.817216          13.240032        8.490240
#
#      prec_MaxValues  prec_Variance  prec_StandardDeviation  \
# ...

# %%
filePath                = '../output/prec_ISB.csv'
DF                      = pd.read_csv(filePath)
DF                      = DF.drop(DF.columns[[0]], axis=1)
display(DF)
DF.plot.line(figsize=((30,10)))
# Out:
#     prec_FileName  prec_AverageValues  prec_MedianValues  prec_MinValues  \
# 0         01-1961          124.336310         124.666230       92.453400
# 1         02-1961           48.054220          46.615837       36.605957
# 2         03-1961           37.080850          36.371494       24.608969
# 3         04-1961          101.938730          98.143430       58.204906
# 4         05-1961           20.180840          18.558178       13.218128
# ..            ...                 ...                ...             ...
# 691       08-2018          167.790650         167.583150      109.616340
# 692       09-2018           71.050530          72.789450       48.928480
# 693       10-2018           14.812920          13.332123        6.623239
# 694       11-2018           22.134710          20.666344        8.053539
# 695       12-2018           13.817216          13.240032        8.490240
#
#      prec_MaxValues  prec_Variance  prec_StandardDeviation
# ...

# %%
filePath                = '../output/tmin_ISB.csv'
DF                      = pd.read_csv(filePath)
DF                      = DF.drop(DF.columns[[0]], axis=1)
display(DF)
DF.plot.line(figsize=((30,10)))
# Out:
#     tmin_FileName  tmin_AverageValues  tmin_MedianValues  tmin_MinValues  \
# 0         01-1961            3.568882           3.940812       -2.369816
# 1         02-1961            3.501463           4.147435       -4.175918
# 2         03-1961            9.606311          10.297916        1.172522
# 3         04-1961           13.917492          14.778236        5.852189
# 4         05-1961           19.007034          20.036194       10.216407
# ..            ...                 ...                ...             ...
# 691       08-2018           23.454490          24.432930       15.975805
# 692       09-2018           20.049519          20.949347       12.541241
# 693       10-2018           13.599517          14.128031        7.604353
# 694       11-2018            7.502071           7.694304        2.900816
# 695       12-2018            3.541865           3.703407       -1.200618
#
#      tmin_MaxValues  tmin_Variance  tmin_StandardDeviation
# ...

# %%
filePath                = '../output/tmax_ISB.csv'
DF                      = pd.read_csv(filePath)
DF                      = DF.drop(DF.columns[[0]], axis=1)
display(DF)
DF.plot.line(figsize=((30,10)))
# Out:
#     tmax_FileName  tmax_AverageValues  tmax_MedianValues  tmax_MinValues  \
# 0         01-1961           16.486372          17.463238        7.840517
# 1         02-1961           15.536664          16.603575        5.517325
# 2         03-1961           22.634838          23.569110       12.680821
# 3         04-1961           27.623022          28.878399       16.427890
# 4         05-1961           34.080776          35.551315       22.026114
# ..            ...                 ...                ...             ...
# 691       08-2018           32.770985          33.771492       24.617922
# 692       09-2018           32.049270          33.134056       22.720482
# 693       10-2018           28.672216          29.745035       19.171915
# 694       11-2018           23.605590          24.606108       14.876918
# 695       12-2018           17.526028          18.414263        9.347421
#
#      tmax_MaxValues  tmax_Variance  tmax_StandardDeviation
# ...

# %%
filePath                = '../output/WET_Yearly.csv'
DF                      = pd.read_csv(filePath)
DF                      = DF.drop(DF.columns[[0]], axis=1)
display(DF)
DF.plot.line(figsize=((30,10)))
# Out:
#       WET_Max    WET_Min   WET_Mean   WET_std
# 0    5.056579  -9.932761  -1.430032  4.744139
# 1    8.634574  -6.032596   0.848418  4.904164
# 2    2.159776  -8.183263  -2.874500  3.290218
# 3   16.404242  -6.717246   5.021743  7.816072
# 4    7.641793  -5.300806   0.404518  4.080901
# 5   11.180202  -9.424407   1.241590  5.922364
# 6    3.375647  -8.834980  -2.506066  4.171322
# 7    6.566977  -8.693543  -1.287285  5.133325
# 8    7.807271  -8.418912  -0.550402  4.460563
# 9    5.449173  -8.458868  -1.192598  4.428433
# 10   2.879228 -11.717257  -3.742840  4.451496
# 11   4.217316 -11.018571  -2.145354  4.440203
# 12   5.109879 -10.278446  -2.029725  4.791594
# 13  10.651196 -10.143499   0.647467  7.127579
# 14   4.350123 -20.538418  -3.233343  7.561367
# 15   5.481196 -21.192805 -11.553794  9.119236
# 16  -8.016744 -21.308247 -14.306941  4.838341
# 17   1.067350 -17.669317  -6.502156  5.543179
# 18   4.030443 -18.154770  -6.553525  7.296040
# ...

# %%
filePath                = '../output/WET_Monthly.csv'
DF                      = pd.read_csv(filePath)
DF                      = DF.drop(DF.columns[[0, 1, 4]], axis=1)
display(DF)
DF.plot.line(figsize=((30,10)))
# Out:
#            WET  WET_Fixed
# 0          NaN        NaN
# 1     5.056579   5.056579
# 2     2.526459   2.526459
# 3          NaN   0.446362
# 4          NaN  -0.964430
# ..         ...        ...
# 227  -4.978644  -4.978644
# 228  -9.763882  -9.763882
# 229 -17.039373 -17.039373
# 230 -15.558002 -15.558002
# 231 -11.970076 -11.970076
#
# [232 rows x 2 columns]
# <AxesSubplot:>
